# %%
LAST_NAME = "BENAVIDEZ"
STUDENT_ID = "TUPM-26-1835"
SEED_DIGIT = int(STUDENT_ID[-1])
FAVORITE_ARTIST = "DILAW"


def validate_reading(value):
    return isinstance(value, (int, float)) and value >= 0


def classify_reading(value):
    if value < 30:
        return "NORMAL"
    elif value < 50:
        return "WARNING"
    else:
        return "CRITICAL"


# GENERATED EQUIPMENT DATA
readings = [
    SEED_DIGIT * 5,
    SEED_DIGIT * 6,
    SEED_DIGIT * 8,
    SEED_DIGIT * 10
]

print("=== GENERATED EQUIPMENT DATA ===")
print("Student:", LAST_NAME)
print("ID:", STUDENT_ID)
print("Favorite Artist:", FAVORITE_ARTIST)
print("Readings:", readings)


# VALIDATION RESULTS
print("\n=== VALIDATION RESULTS ===")

valid_readings = []

for reading in readings:
    result = validate_reading(reading)

    print(reading, "->", "VALID" if result else "INVALID")

    if result:
        valid_readings.append(reading)


# DIAGNOSTIC RESULTS
print("\n=== DIAGNOSTIC RESULTS ===")

for reading in valid_readings:
    print(reading, "->", classify_reading(reading))


# EXECUTION LOG
print("\n=== EXECUTION LOG ===")
print("1. Equipment data generated.")
print("2. Readings validated.")
print("3. Valid readings classified.")
print("4. Diagnostic analysis completed.")


# FINAL OUTPUT
print("\n=== FINAL OUTPUT ===")

critical = sum(
    1 for reading in valid_readings
    if classify_reading(reading) == "CRITICAL"
)

warning = sum(
    1 for reading in valid_readings
    if classify_reading(reading) == "WARNING"
)

normal = sum(
    1 for reading in valid_readings
    if classify_reading(reading) == "NORMAL"
)

print("NORMAL:", normal)
print("WARNING:", warning)
print("CRITICAL:", critical)

if critical > 0:
    print("Final Status: CRITICAL")
elif warning > 0:
    print("Final Status: WARNING")
else:
    print("Final Status: NORMAL")
# Out:
# === GENERATED EQUIPMENT DATA ===
# Student: BENAVIDEZ
# ID: TUPM-26-1835
# Favorite Artist: DILAW
# Readings: [25, 30, 40, 50]
#
# === VALIDATION RESULTS ===
# 25 -> VALID
# 30 -> VALID
# 40 -> VALID
# 50 -> VALID
#
# === DIAGNOSTIC RESULTS ===
# 25 -> NORMAL
# 30 -> WARNING
# 40 -> WARNING
# 50 -> CRITICAL
#
# === EXECUTION LOG ===
# 1. Equipment data generated.
# 2. Readings validated.
# 3. Valid readings classified.
# 4. Diagnostic analysis completed.
#
# === FINAL OUTPUT ===
# NORMAL: 1
# WARNING: 2
# CRITICAL: 1
# Final Status: CRITICAL

# %%
LAST_NAME = "BENAVIDEZ"
STUDENT_ID = "TUPM-26-1835"
SEED_DIGIT = int(STUDENT_ID[-1])
FAVORITE_ARTIST = "DILAW"


# Generate student-specific numeric fault code
fault_code = int(
    str(SEED_DIGIT) +
    str(len(LAST_NAME)) +
    str(len(FAVORITE_ARTIST))
)

print("=== GENERATED FAULT DATA ===")
print("Fault Code:", fault_code)


# Recursive fault trace
trace = []


def fault_trace(code):
    trace.append(code)

    # Base condition
    if code < 10:
        return

    # Recursive call
    fault_trace(code // 10)


fault_trace(fault_code)


# Validation Results
print("\n=== VALIDATION RESULTS ===")

if fault_code > 0:
    print("Fault code is valid.")
else:
    print("Fault code is invalid.")


# Diagnostic Results
print("\n=== DIAGNOSTIC RESULTS ===")

print("Recursive Trace:", " -> ".join(map(str, trace)))
print("Termination Value:", trace[-1])


# Number of Recursive Calls
print("Number of Recursive Calls:", len(trace))


# Execution Log
print("\n=== EXECUTION LOG ===")
for i, value in enumerate(trace, 1):
    print("Call", i, ":", value)


# Final Output
print("\n=== FINAL OUTPUT ===")
print("Fault Trace Completed.")
print("Final Fault Value:", trace[-1])
# Out:
# === GENERATED FAULT DATA ===
# Fault Code: 595
#
# === VALIDATION RESULTS ===
# Fault code is valid.
#
# === DIAGNOSTIC RESULTS ===
# Recursive Trace: 595 -> 59 -> 5
# Termination Value: 5
# Number of Recursive Calls: 3
#
# === EXECUTION LOG ===
# Call 1 : 595
# Call 2 : 59
# Call 3 : 5
#
# === FINAL OUTPUT ===
# Fault Trace Completed.
# Final Fault Value: 5

# %%
LAST_NAME = "BENAVIDEZ"
STUDENT_ID = "TUPM-26-1835"
SEED_DIGIT = int(STUDENT_ID[-1])
FAVORITE_ARTIST = "DILAW"


# ==============================
# STUDENT-SPECIFIC INPUTS
# ==============================

print("=== STUDENT-SPECIFIC INPUTS ===")
print("LAST NAME:", LAST_NAME)
print("STUDENT ID:", STUDENT_ID)
print("SEED DIGIT:", SEED_DIGIT)
print("FAVORITE ARTIST:", FAVORITE_ARTIST)


# ==============================
# GENERATOR
# ==============================

def generate_telemetry():
    base = SEED_DIGIT + len(LAST_NAME) + len(FAVORITE_ARTIST)

    for i in range(1, 11):
        if i == 6:
            yield "INVALID"
        else:
            yield base * i


# ==============================
# VALIDATION
# ==============================

def validate_telemetry(value):
    if not isinstance(value, (int, float)):
        raise ValueError("Invalid telemetry value")

    if value < 0:
        raise ValueError("Negative telemetry value")

    return value


# ==============================
# DECORATOR
# ==============================

def monitor(function):
    def wrapper(*args, **kwargs):
        print("\nProcessing started...")
        result = function(*args, **kwargs)
        print("Processing completed.")
        return result

    return wrapper


# ==============================
# RECURSION
# ==============================

def recursive_analysis(abnormal, index=0, trace=None):

    if trace is None:
        trace = []

    # Base condition
    if index >= len(abnormal):
        return trace

    trace.append(abnormal[index])

    return recursive_analysis(abnormal, index + 1, trace)


# ==============================
# MAIN PROCESSING FUNCTION
# ==============================

@monitor
def process_telemetry():

    valid_count = 0
    invalid_count = 0
    processed_count = 0

    processed_data = []
    abnormal_data = []

    # Lambda transformation
    transform = lambda x: round(x * 1.10, 2)

    print("\n=== GENERATED TELEMETRY DATA ===")

    # Generator processes data one at a time
    for value in generate_telemetry():

        print("Generated:", value)

        try:
            valid_value = validate_telemetry(value)
            valid_count += 1

            processed_value = transform(valid_value)
            processed_data.append(processed_value)

            processed_count += 1

            # Detect abnormal condition
            if processed_value >= 50:
                abnormal_data.append(processed_value)

        except (ValueError, TypeError) as error:
            invalid_count += 1
            print("Invalid reading:", error)

    # Recursive analysis
    recursive_trace = recursive_analysis(abnormal_data)

    # Returned diagnostic report
    return {
        "processed": processed_count,
        "valid": valid_count,
        "invalid": invalid_count,
        "processed_data": processed_data,
        "abnormal": abnormal_data,
        "recursive_trace": recursive_trace
    }


# ==============================
# DIAGNOSTIC REPORT
# ==============================

report = process_telemetry()


print("\n=== VALID / INVALID RESULTS ===")
print("Valid Readings:", report["valid"])
print("Invalid Readings:", report["invalid"])


print("\n=== PROCESSED RESULTS ===")
print("Processed Readings:", report["processed"])
print("Processed Data:", report["processed_data"])


print("\n=== RECURSIVE ANALYSIS ===")
print("Abnormal Conditions:", report["abnormal"])
print("Recursive Trace:", report["recursive_trace"])


print("\n=== FINAL DIAGNOSTIC SUMMARY ===")

if report["abnormal"]:
    status = "ABNORMAL"
else:
    status = "NORMAL"

print("Processed Readings:", report["processed"])
print("Valid Readings:", report["valid"])
print("Invalid Readings:", report["invalid"])
print("Detected Abnormal Conditions:", len(report["abnormal"]))
print("Overall Equipment Status:", status)


print("\n=== EXECUTION LOG ===")
print("Telemetry generated using student-specific inputs.")
print("Generator processed readings one at a time.")
print("Invalid telemetry values were handled.")
print("Lambda transformation applied.")
print("Decorator monitored the processing function.")
print("Recursive analysis completed.")
print("Final diagnostic report generated.")


print("\n=== FINAL OUTPUT ===")
print("Equipment Status:", status)
# Out:
# === STUDENT-SPECIFIC INPUTS ===
# LAST NAME: BENAVIDEZ
# STUDENT ID: TUPM-26-1835
# SEED DIGIT: 5
# FAVORITE ARTIST: DILAW
#
# Processing started...
#
# === GENERATED TELEMETRY DATA ===
# Generated: 19
# Generated: 38
# Generated: 57
# Generated: 76
# Generated: 95
# Generated: INVALID
# Invalid reading: Invalid telemetry value
# Generated: 133
# Generated: 152
# Generated: 171
# Generated: 190
# Processing completed.
#
# === VALID / INVALID RESULTS ===
# Valid Readings: 9
# Invalid Readings: 1
#
# === PROCESSED RESULTS ===
# Processed Readings: 9
# Processed Data: [20.9, 41.8, 62.7, 83.6, 104.5, 146.3, 167.2, 188.1, 209.0]
#
# === RECURSIVE ANALYSIS ===
# Abnormal Conditions: [62.7, 83.6, 104.5, 146.3, 167.2, 188.1, 209.0]
# Recursive Trace: [62.7, 83.6, 104.5, 146.3, 167.2, 188.1, 209.0]
#
# === FINAL DIAGNOSTIC SUMMARY ===
# Processed Readings: 9
# Valid Readings: 9
# Invalid Readings: 1
# Detected Abnormal Conditions: 7
# Overall Equipment Status: ABNORMAL
#
# === EXECUTION LOG ===
# Telemetry generated using student-specific inputs.
# Generator processed readings one at a time.
# Invalid telemetry values were handled.
# Lambda transformation applied.
# Decorator monitored the processing function.
# Recursive analysis completed.
# Final diagnostic report generated.
#
# === FINAL OUTPUT ===
# Equipment Status: ABNORMAL
